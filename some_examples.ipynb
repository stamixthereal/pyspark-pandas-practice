# %% [markdown]
# ### Анализ датасета

# %%
from pyspark.sql import SparkSession
import pandas as pd


spark = SparkSession.builder.appName('test').getOrCreate()
df = spark.read.csv('new_data.csv', header=True, inferSchema=True)
df.count()
# Out:
# 1000

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://STAMIX:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = pd.read_table('new_data.csv', sep=',')
data.head()
# Out:
#    Unnamed: 0  trip_id  year  month  week  day  hour    usertype  gender  \
# 0           0  2355134  2014      6    27    0    23  Subscriber    Male
# 1           1  2355133  2014      6    27    0    23  Subscriber    Male
# 2           2  2355130  2014      6    27    0    23  Subscriber    Male
# 3           3  2355129  2014      6    27    0    23  Subscriber  Female
# 4           4  2355128  2014      6    27    0    23  Subscriber  Female
#
#              starttime  ... from_station_id            from_station_name  \
# 0  2014-06-30 23:57:00  ...             131    Lincoln Ave & Belmont Ave
# 1  2014-06-30 23:56:00  ...             282      Halsted St & Maxwell St
# 2  2014-06-30 23:33:00  ...             327  Sheffield Ave & Webster Ave
# 3  2014-06-30 23:26:00  ...             134     Peoria St & Jackson Blvd
# 4  2014-06-30 23:16:00  ...             320     Loomis St & Lexington St
#
#    latitude_start longitude_start  dpcapacity_start to_station_id  \
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- trip_id: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- week: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- usertype: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- starttime: string (nullable = true)
#  |-- stoptime: string (nullable = true)
#  |-- tripduration: double (nullable = true)
#  |-- temperature: double (nullable = true)
#  |-- events: string (nullable = true)
#  |-- from_station_id: integer (nullable = true)
#  |-- from_station_name: string (nullable = true)
#  |-- latitude_start: double (nullable = true)
#  |-- longitude_start: double (nullable = true)
#  |-- dpcapacity_start: double (nullable = true)
#  |-- to_station_id: integer (nullable = true)
#  |-- to_station_name: string (nullable = true)
#  |-- latitude_end: double (nullable = true)
# ...

# %%
df.first()
# Out:
# Row(_c0=0, trip_id=2355134, year=2014, month=6, week=27, day=0, hour=23, usertype='Subscriber', gender='Male', starttime='2014-06-30 23:57:00', stoptime='2014-07-01 00:07:00', tripduration=10.066666666666666, temperature=68.0, events='tstorms', from_station_id=131, from_station_name='Lincoln Ave & Belmont Ave', latitude_start=41.939365, longitude_start=-87.668385, dpcapacity_start=15.0, to_station_id=303, to_station_name='Broadway & Cornelia Ave', latitude_end=41.945512, longitude_end=-87.64598000000001, dpcapacity_end=15.0)

# %%
df.head(2)
# Out:
# [Row(_c0=0, trip_id=2355134, year=2014, month=6, week=27, day=0, hour=23, usertype='Subscriber', gender='Male', starttime='2014-06-30 23:57:00', stoptime='2014-07-01 00:07:00', tripduration=10.066666666666666, temperature=68.0, events='tstorms', from_station_id=131, from_station_name='Lincoln Ave & Belmont Ave', latitude_start=41.939365, longitude_start=-87.668385, dpcapacity_start=15.0, to_station_id=303, to_station_name='Broadway & Cornelia Ave', latitude_end=41.945512, longitude_end=-87.64598000000001, dpcapacity_end=15.0),
# ...

# %%
df.show(2, truncate=True)
# Out:
# +---+-------+----+-----+----+---+----+----------+------+-------------------+-------------------+------------------+-----------+-------+---------------+--------------------+--------------+---------------+----------------+-------------+--------------------+------------+------------------+--------------+
# |_c0|trip_id|year|month|week|day|hour|  usertype|gender|          starttime|           stoptime|      tripduration|temperature| events|from_station_id|   from_station_name|latitude_start|longitude_start|dpcapacity_start|to_station_id|     to_station_name|latitude_end|     longitude_end|dpcapacity_end|
# +---+-------+----+-----+----+---+----+----------+------+-------------------+-------------------+------------------+-----------+-------+---------------+--------------------+--------------+---------------+----------------+-------------+--------------------+------------+------------------+--------------+
# ...

# %%
df.columns
# Out:
# ['_c0',
#  'trip_id',
#  'year',
#  'month',
#  'week',
#  'day',
#  'hour',
#  'usertype',
#  'gender',
#  'starttime',
#  'stoptime',
#  'tripduration',
#  'temperature',
#  'events',
#  'from_station_id',
#  'from_station_name',
#  'latitude_start',
#  'longitude_start',
#  'dpcapacity_start',
#  'to_station_id',
#  'to_station_name',
#  'latitude_end',
#  'longitude_end',
#  'dpcapacity_end']

# %%
df.describe().toPandas()
# Out:
#   summary                _c0            trip_id    year month  week   day  \
# 0   count               1000               1000    1000  1000  1000  1000
# 1    mean              499.5        2354059.862  2014.0   6.0  27.0   0.0
# 2  stddev  288.8194360957494  531.4795324843233     0.0   0.0   0.0   0.0
# 3     min                  0            2353212    2014     6    27     0
# 4     max                999            2355134    2014     6    27     0
#
#                  hour    usertype  gender  ...    from_station_id  \
# 0                1000        1000    1000  ...               1000
# 1              18.247        None    None  ...            157.369
# 2  1.1212708184235645        None    None  ...  95.51553830166617
# 3                  17  Subscriber  Female  ...                  5
# 4                  23  Subscriber    Male  ...                350
#
#         from_station_name        latitude_start      longitude_start  \
# ...

# %%
df.na.drop().describe('latitude_start').show()
# Out:
# +-------+--------------------+
# |summary|      latitude_start|
# +-------+--------------------+
# |  count|                1000|
# |   mean|   41.89987679301433|
# | stddev|0.029062590873093153|
# |    min|           41.788746|
# |    max|           41.973385|
# +-------+--------------------+
